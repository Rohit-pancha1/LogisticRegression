# %%
import pandas as pd
df= pd.read_csv('locality.csv')
df.head(1)
# Out:
#    area(sq ft) locality      price
# 0          550  station  1000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   area(sq ft)  14 non-null     int64
#  1   locality     14 non-null     object
#  2   price        14 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 468.0+ bytes

# %%
# dummy
# one hot encoding

# %%
dummy = pd. get_dummies(df.locality)
dummy
# Out:
#     center  newcity    old  oldcity  station
# 0    False    False  False    False     True
# 1     True    False  False    False    False
# 2    False    False   True    False    False
# 3    False     True  False    False    False
# 4    False    False   True    False    False
# 5     True    False  False    False    False
# 6    False    False  False    False     True
# 7    False     True  False    False    False
# 8    False    False  False    False     True
# 9     True    False  False    False    False
# 10   False     True  False    False    False
# 11   False    False  False     True    False
# 12    True    False  False    False    False
# 13   False    False   True    False    False

# %%
merged= pd.concat([df, dummy], axis = 'columns')
merged
# Out:
#     area(sq ft) locality        price  center  newcity    old  oldcity  \
# 0           550  station  1000000.000   False    False  False    False
# 1           600   center  1200000.000    True    False  False    False
# 2           650      old  1500000.000   False    False   True    False
# 3          1000  newcity  3233333.333   False     True  False    False
# 4          1050      old  3483333.333   False    False   True    False
# 5          1100   center  3733333.333    True    False  False    False
# 6          1150  station  3983333.333   False    False  False    False
# 7          1540  newcity  5000000.000   False     True  False    False
# 8          2000  station  6000000.000   False    False  False    False
# 9          1881   center  6309259.259    True    False  False    False
# 10         2043  newcity  6923703.703   False     True  False    False
# 11         2205  oldcity  7538148.148   False    False  False     True
# 12         2367   center  8152592.592    True    False  False    False
# 13         2529      old  8767037.037   False    False   True    False
#
#     station
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False

# %%
a= merged.drop(['locality'], axis= 'columns')
a
# Out:
#     area(sq ft)        price  center  newcity    old  oldcity  station
# 0           550  1000000.000   False    False  False    False     True
# 1           600  1200000.000    True    False  False    False    False
# 2           650  1500000.000   False    False   True    False    False
# 3          1000  3233333.333   False     True  False    False    False
# 4          1050  3483333.333   False    False   True    False    False
# 5          1100  3733333.333    True    False  False    False    False
# 6          1150  3983333.333   False    False  False    False     True
# 7          1540  5000000.000   False     True  False    False    False
# 8          2000  6000000.000   False    False  False    False     True
# 9          1881  6309259.259    True    False  False    False    False
# 10         2043  6923703.703   False     True  False    False    False
# 11         2205  7538148.148   False    False  False     True    False
# 12         2367  8152592.592    True    False  False    False    False
# 13         2529  8767037.037   False    False   True    False    False

# %%
a.replace([True, False], [1,0], inplace =True)

# %%
a
# Out:
#     area(sq ft)        price  center  newcity  old  oldcity  station
# 0           550  1000000.000       0        0    0        0        1
# 1           600  1200000.000       1        0    0        0        0
# 2           650  1500000.000       0        0    1        0        0
# 3          1000  3233333.333       0        1    0        0        0
# 4          1050  3483333.333       0        0    1        0        0
# 5          1100  3733333.333       1        0    0        0        0
# 6          1150  3983333.333       0        0    0        0        1
# 7          1540  5000000.000       0        1    0        0        0
# 8          2000  6000000.000       0        0    0        0        1
# 9          1881  6309259.259       1        0    0        0        0
# 10         2043  6923703.703       0        1    0        0        0
# 11         2205  7538148.148       0        0    0        1        0
# 12         2367  8152592.592       1        0    0        0        0
# 13         2529  8767037.037       0        0    1        0        0

# %%
# One Hot in coding

# %%
import pandas as pd
df= pd.read_csv('locality.csv')
df.head(1)
# Out:
#    area(sq ft) locality      price
# 0          550  station  1000000.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a= df

# %%
a.locality = le.fit_transform(a.locality)

# %%
a
# Out:
#     area(sq ft)  locality        price
# 0           550         4  1000000.000
# 1           600         0  1200000.000
# 2           650         2  1500000.000
# 3          1000         1  3233333.333
# 4          1050         2  3483333.333
# 5          1100         0  3733333.333
# 6          1150         4  3983333.333
# 7          1540         1  5000000.000
# 8          2000         4  6000000.000
# 9          1881         0  6309259.259
# 10         2043         1  6923703.703
# 11         2205         3  7538148.148
# 12         2367         0  8152592.592
# 13         2529         2  8767037.037

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(a.drop('price', axis='columns'),a.price)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -624883.9324813578

# %%
model.coef_
# Out:
# array([  3722.52360092, -56395.87863413])

# %%
model.predict([[1500,0]])
# Out:
# C:\Users\rohit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4958901.46889475])

# %%
a.to_csv('locality1.csv')

# %%
a
# Out:
#     area(sq ft)  locality        price
# 0           550         4  1000000.000
# 1           600         0  1200000.000
# 2           650         2  1500000.000
# 3          1000         1  3233333.333
# 4          1050         2  3483333.333
# 5          1100         0  3733333.333
# 6          1150         4  3983333.333
# 7          1540         1  5000000.000
# 8          2000         4  6000000.000
# 9          1881         0  6309259.259
# 10         2043         1  6923703.703
# 11         2205         3  7538148.148
# 12         2367         0  8152592.592
# 13         2529         2  8767037.037
